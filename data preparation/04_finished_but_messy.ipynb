# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
# Load Test data from our github repo
url_test = 'https://raw.githubusercontent.com/tjayada/iANNwTF_Project/main/data/Test.csv'
dataDF_test = pd.read_csv(url_test)

# Load Train data from our github repo
url_train = 'https://raw.githubusercontent.com/tjayada/iANNwTF_Project/main/data/Train.csv'
dataDF_train = pd.read_csv(url_train)

# %%
# create data without clomumns 70 - 76 and drop NaN's

# for test date
data_without_columns_test = dataDF_test.copy()
data_without_columns_test = data_without_columns_test.drop(["L3_CH4_CH4_column_volume_mixing_ratio_dry_air", "L3_CH4_aerosol_height", "L3_CH4_aerosol_optical_depth",
                                      "L3_CH4_sensor_azimuth_angle", "L3_CH4_sensor_zenith_angle", "L3_CH4_solar_azimuth_angle", "L3_CH4_solar_zenith_angle"], axis=1)
data_without_columns_test = data_without_columns_test.dropna()

# for train data
data_without_columns_train = dataDF_train.copy()
data_without_columns_train = data_without_columns_train.drop(["L3_CH4_CH4_column_volume_mixing_ratio_dry_air", "L3_CH4_aerosol_height", "L3_CH4_aerosol_optical_depth",
                                      "L3_CH4_sensor_azimuth_angle", "L3_CH4_sensor_zenith_angle", "L3_CH4_solar_azimuth_angle", "L3_CH4_solar_zenith_angle"], axis=1)
data_without_columns_train = data_without_columns_train.dropna()

# %%
# remove targets and create labels

data_without_columns_train_labels = data_without_columns_train[['target']]
data_without_columns_train = data_without_columns_train.drop(["target", "target_min", "target_max", "target_variance", "target_count"], axis=1)

# %%
# normalize data

# for test data
x = data_without_columns_test.iloc[:,3:]
data_without_columns_test.iloc[:,3:] = (x-x.min())/ (x.max() - x.min())

# for train data
x = data_without_columns_train.iloc[:,3:]
data_without_columns_train.iloc[:,3:] = (x-x.min())/ (x.max() - x.min())

# %%
# convert dates to datetime 

data_without_columns_test['date'] = pd.to_datetime(data_without_columns_test['Date'],format='%Y-%m-%d')
data_without_columns_train['date'] = pd.to_datetime(data_without_columns_train['Date'],format='%Y-%m-%d')



# add weekdays based on dates

data_without_columns_test['weekday'] = data_without_columns_test['date'].dt.weekday
data_without_columns_train['weekday'] = data_without_columns_train['date'].dt.weekday


# add whether the date is a weekend or not, 0 is no and 1 is yes

data_without_columns_test['weekend'] = np.multiply((data_without_columns_test['date'].dt.weekday >= 5), 1)
data_without_columns_train['weekend'] = np.multiply((data_without_columns_train['date'].dt.weekday >= 5),1)



# add month based on dates

data_without_columns_test['month'] = data_without_columns_test['date'].dt.month
data_without_columns_train['month'] = data_without_columns_train['date'].dt.month


# add which day out of all days in the year it is

data_without_columns_test['dayofyear'] = data_without_columns_test['date'].dt.dayofyear
data_without_columns_train['dayofyear'] = data_without_columns_train['date'].dt.dayofyear


# what quarter is the date part of

data_without_columns_test['quarter'] = data_without_columns_test['date'].dt.quarter
data_without_columns_train['quarter'] = data_without_columns_train['date'].dt.quarter

# %%
data_without_columns_test.head()
# Out:
#         Place_ID X Date        Date Place_ID  \
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX
# 1  0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX
# 2  0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX
# 3  0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX
# 4  0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 0                              0.177392                           0.252598
# 1                              0.288469                           0.389108
# 2                              0.276863                           0.371910
# 3                              0.233957                           0.498746
# 4                              0.145892                           0.697599
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# 0                           0.191509                     0.688186
# 1                           0.284971                     0.694349
# ...

# %%
###################################################################################################################################

# %%
# create data set with mean values as replacement for NaN's

# for test data
data_with_mean_NaN_test = dataDF_test.copy()
data_with_mean_NaN_test = data_with_mean_NaN_test.fillna(data_with_mean_NaN_test.mean())

# for train data
data_with_mean_NaN_train = dataDF_train.copy()
data_with_mean_NaN_train = data_with_mean_NaN_train.fillna(data_with_mean_NaN_train.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   if __name__ == '__main__':

# %%
# remove targets and create labels

data_with_mean_NaN_train_labels = data_with_mean_NaN_train[['target']]
data_with_mean_NaN_train = data_with_mean_NaN_train.drop(["target", "target_min", "target_max", "target_variance", "target_count"], axis=1)

# %%
# normalize data

# for test data
x = data_with_mean_NaN_test.iloc[:,3:]
data_with_mean_NaN_test.iloc[:,3:] = (x-x.min())/ (x.max() - x.min())

# for train data
x = data_with_mean_NaN_train.iloc[:,3:]
data_with_mean_NaN_train.iloc[:,3:] = (x-x.min())/ (x.max() - x.min())

# %%
# convert dates to datetime 
# useless now

data_with_mean_NaN_test['date'] = pd.to_datetime(data_with_mean_NaN_test['Date'],format='%Y-%m-%d')
data_with_mean_NaN_train['date'] = pd.to_datetime(data_with_mean_NaN_train['Date'],format='%Y-%m-%d')



# add weekdays based on dates

data_with_mean_NaN_test['weekday'] = data_with_mean_NaN_test['date'].dt.weekday
data_with_mean_NaN_train['weekday'] = data_with_mean_NaN_train['date'].dt.weekday


# add whether the date is a weekend or not, 0 is no and 1 is yes

data_with_mean_NaN_test['weekend'] = np.multiply((data_with_mean_NaN_test['date'].dt.weekday >= 5),1)
data_with_mean_NaN_train['weekend'] = np.multiply((data_with_mean_NaN_train['date'].dt.weekday >= 5),1)



# add month based on dates

data_with_mean_NaN_test['month'] = data_with_mean_NaN_test['date'].dt.month
data_with_mean_NaN_train['month'] = data_with_mean_NaN_train['date'].dt.month


# add which day out of all days in the year it is

data_with_mean_NaN_test['dayofyear'] = data_with_mean_NaN_test['date'].dt.dayofyear
data_with_mean_NaN_train['dayofyear'] = data_with_mean_NaN_train['date'].dt.dayofyear


# what quarter is the date part of

data_with_mean_NaN_test['quarter'] = data_with_mean_NaN_test['date'].dt.quarter
data_with_mean_NaN_train['quarter'] = data_with_mean_NaN_train['date'].dt.quarter

# %%
data_with_mean_NaN_test.head()
# Out:
#         Place_ID X Date        Date Place_ID  \
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX
# 1  0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX
# 2  0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX
# 3  0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX
# 4  0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 0                              0.172026                           0.251876
# 1                              0.279743                           0.387996
# 2                              0.268489                           0.370847
# 3                              0.226880                           0.497320
# 4                              0.141479                           0.695606
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# 0                           0.191509                     0.671532
# 1                           0.284971                     0.677546
# ...

# %%
data_with_mean_NaN_test.groupby('Place_ID').count()
# Out:
#           Place_ID X Date  Date  precipitable_water_entire_atmosphere  \
# Place_ID
# 0OS9LVX                94    94                                    94
# 0Q2LTOG                94    94                                    94
# 15WCXN1                94    94                                    94
# 19090SM                69    69                                    69
# 1BD5TVT                94    94                                    94
# ...                   ...   ...                                   ...
# YY9I2R1                94    94                                    94
# YYOM5TU                94    94                                    94
# Z2XYMS4                94    94                                    94
# ZIESWTR                94    94                                    94
# ZZDJZMS                94    94                                    94
#
#           relative_humidity_2m_above_ground  \
# Place_ID
# 0OS9LVX                                  94
# ...

# %%
data_with_mean_NaN_train.groupby('Place_ID').count()
# Out:
#           Place_ID X Date  Date  precipitable_water_entire_atmosphere  \
# Place_ID
# 010Q650                94    94                                    94
# 05EC30X                90    90                                    90
# 0DPWHX8                94    94                                    94
# 0GBXTHY                94    94                                    94
# 0HYPV1N                94    94                                    94
# ...                   ...   ...                                   ...
# YLLOKEY                94    94                                    94
# YLZOBFW                94    94                                    94
# YPXSK14                94    94                                    94
# YSIXKFZ                94    94                                    94
# YWSFY6Q                78    78                                    78
#
#           relative_humidity_2m_above_ground  \
# Place_ID
# 010Q650                                  94
# ...

# %%
# train and test cities are not the same -> cant use any location information for prediction -> drop location ID
# multivariate time series forecasting is really dificult to implement, since we need to use the dates of the data for this,
# but the dates are not sorted, in that different locations have the same dates and different locations are independet of each other, 
# so the right prediction from the 5th of march to the 15th of march for place A does give us no indication for place B in the same exact time frame,
# so we would need a LSTM for every single city (?) which is not possible with over 300 cities in the train data alone

# %%
# find out most important features through PCA

from sklearn.decomposition import PCA

test_data = data_with_mean_NaN_test.copy()
test_data = test_data.drop(["Place_ID", "Place_ID X Date", "Date", "date", "weekday", "month","weekend","quarter","dayofyear"], axis = 1)

# just tried around and found out that 6 features are the best match
pca = PCA(n_components=6).fit(test_data)

# number of components, in our case 6
number_of_components = pca.components_.shape[0]

# get the index of the most important features
most_important = []
for component in range(number_of_components):
  most_important.append(abs(pca.components_[component]).argmax())

initial_feature_names = data_with_mean_NaN_test.columns
# get the names of the most important features
most_important_names = []
for name in range(number_of_components):
  most_important_names.append(initial_feature_names[most_important[name]])

# individual features importance in descending order
for i in range(number_of_components):
  print(most_important_names[i] + " explains " + str(np.round(pca.explained_variance_ratio_[i] * 100)) + "% of the variance \n")

# total explainibility of all six features combined
print("\n All six features together can explain " + str(np.round(sum(pca.explained_variance_ratio_)*100)) + "% of the variance")
# Out:
# L3_CLOUD_cloud_optical_depth explains 26.0% of the variance
#
# L3_O3_O3_effective_temperature explains 17.0% of the variance
#
# L3_NO2_tropospheric_NO2_column_number_density explains 13.0% of the variance
#
# L3_NO2_NO2_slant_column_number_density explains 8.0% of the variance
#
# L3_O3_cloud_fraction explains 7.0% of the variance
#
# L3_HCHO_tropospheric_HCHO_column_number_density explains 4.0% of the variance
#
#
#  All six features together can explain 74.0% of the variance

# %%
# we now get the data of each of these important features and "insert" it into the next data point, as an example a Tuesday 
# also has the data of the important features of Monday and so on.
# So we have the benefit of a sequential model, without implementing it, since it is not possible with our kind of data.

# %%
test_drive = data_with_mean_NaN_test.copy()
test_drive[most_important_names[0] + "_NEU_" + str(1)] = 0

# %%
test_drive.head()
# Out:
#         Place_ID X Date        Date Place_ID  \
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX
# 1  0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX
# 2  0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX
# 3  0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX
# 4  0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 0                              0.172026                           0.251876
# 1                              0.279743                           0.387996
# 2                              0.268489                           0.370847
# 3                              0.226880                           0.497320
# 4                              0.141479                           0.695606
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# 0                           0.191509                     0.671532
# 1                           0.284971                     0.677546
# ...

# %%
# the idea is to shift the data set by one, but since different locations are independent of each other, we cant shift a value from
# one location to another location. To avoid this we tried to compare the location id's and if they are the same, we then go ahead
# and add the shifted value
# spoiler alert: this doesnt work for some reason

shifted_data_with_mean_NaN_test = data_with_mean_NaN_test.copy()
shifted_data_with_mean_NaN_test = shifted_data_with_mean_NaN_test.shift(1)



for i in range(len(test_drive)):
  if test_drive.at[i, 'Place_ID'] == shifted_data_with_mean_NaN_test.at[i, 'Place_ID']:
    test_drive.at[i, 'L3_CLOUD_cloud_optical_depth_NEU_1'] = shifted_data_with_mean_NaN_test.at[i, 'L3_CLOUD_cloud_optical_depth']

# %%
# addded the original data to the dataset again, so they are next to each other and better to compare
# here we can see, that the shifted data is vastly different then the original, which i do not understand at all
test_drive["original_L3_CLOUD_cloud_optical_depth"] = test_drive['L3_CLOUD_cloud_optical_depth']
test_drive.describe()
# Out:
#        precipitable_water_entire_atmosphere  \
# count                          16136.000000
# mean                               0.213860
# std                                0.150757
# min                                0.000000
# 25%                                0.108606
# 50%                                0.172026
# 75%                                0.276527
# max                                1.000000
#
#        relative_humidity_2m_above_ground  specific_humidity_2m_above_ground  \
# count                       16136.000000                       16136.000000
# mean                            0.690636                           0.263010
# std                             0.196758                           0.163842
# min                             0.000000                           0.000000
# 25%                             0.571275                           0.156906
# 50%                             0.729904                           0.217638
# ...

# %%
# we have created these before, when we used PCA to figure out the most important features in the dataset
# just a quick look for understanding
print(most_important_names)

# go through each important feature and put a shifted copy of it as a new feature in the data
# we use a shift of 1, so we will have the data of the important feature of the 1 day before as well
# room for improvement: we shifted all the data even though the locations change in between
# so the better approach would be to look at the locations and only shift in these intervals, but 
# this made us problems for some reason, as mentioned above
for name in most_important_names:
    for i in range(1):
        data_with_mean_NaN_train[name+'_of_'+str(i+1)+'_day_before'] = data_with_mean_NaN_train[name].shift(i+1)
        data_with_mean_NaN_test[name+'_of_'+str(i+1)+'_day_before'] = data_with_mean_NaN_test[name].shift(i+1)

        data_without_columns_train[name+'_of_'+str(i+1)+'_day_before'] = data_without_columns_train[name].shift(i+1)
        data_without_columns_test[name+'_of_'+str(i+1)+'_day_before'] = data_without_columns_test[name].shift(i+1)
# Out:
# ['L3_CLOUD_cloud_optical_depth', 'L3_O3_O3_effective_temperature', 'L3_NO2_tropospheric_NO2_column_number_density', 'L3_NO2_NO2_slant_column_number_density', 'L3_O3_cloud_fraction', 'L3_HCHO_tropospheric_HCHO_column_number_density']

# %%
data_with_mean_NaN_test.head()
# Out:
#         Place_ID X Date        Date Place_ID  \
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX
# 1  0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX
# 2  0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX
# 3  0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX
# 4  0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 0                              0.172026                           0.251876
# 1                              0.279743                           0.387996
# 2                              0.268489                           0.370847
# 3                              0.226880                           0.497320
# 4                              0.141479                           0.695606
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# 0                           0.191509                     0.671532
# 1                           0.284971                     0.677546
# ...

# %%
data_without_columns_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18219 entries, 1 to 30555
# Data columns (total 82 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Place_ID X Date                                                  18219 non-null  object
#  1   Date                                                             18219 non-null  object
#  2   Place_ID                                                         18219 non-null  object
#  3   precipitable_water_entire_atmosphere                             18219 non-null  float64
#  4   relative_humidity_2m_above_ground                                18219 non-null  float64
#  5   specific_humidity_2m_above_ground                                18219 non-null  float64
#  6   temperature_2m_above_ground                                      18219 non-null  float64
# ...

# %%
# through shifting we have created (1) NaN's once again, so we need to drop that row
# we also need to drop the locations and dates as they have no use for us and do not work in our planned model

# drop NaN's

data_with_mean_NaN_train = data_with_mean_NaN_train.dropna()
data_with_mean_NaN_test = data_with_mean_NaN_test.dropna()

data_without_columns_train = data_without_columns_train.dropna()
data_without_columns_test = data_without_columns_test.dropna()


# drop dates and locations
data_with_mean_NaN_train = data_with_mean_NaN_train.drop(["Place_ID X Date", "Date", "Place_ID", "date"], axis = 1)
data_with_mean_NaN_test = data_with_mean_NaN_test.drop(["Place_ID X Date", "Date", "Place_ID"], axis = 1)

data_without_columns_train = data_without_columns_train.drop(["Place_ID X Date", "Date", "Place_ID", "date"], axis = 1)
data_without_columns_test = data_without_columns_test.drop(["Place_ID X Date", "Date", "Place_ID", "date"], axis = 1)

# %%
data_without_columns_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18218 entries, 2 to 30555
# Data columns (total 78 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   precipitable_water_entire_atmosphere                             18218 non-null  float64
#  1   relative_humidity_2m_above_ground                                18218 non-null  float64
#  2   specific_humidity_2m_above_ground                                18218 non-null  float64
#  3   temperature_2m_above_ground                                      18218 non-null  float64
#  4   u_component_of_wind_10m_above_ground                             18218 non-null  float64
#  5   v_component_of_wind_10m_above_ground                             18218 non-null  float64
#  6   L3_NO2_NO2_column_number_density                                 18218 non-null  float64
# ...
